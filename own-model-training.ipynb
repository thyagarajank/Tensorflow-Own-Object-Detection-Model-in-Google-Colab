# %% [markdown]
# # Tensorflow Own Object Detection Model in Google Colab
# Model Training [Part-1]

# %% [markdown]
# Created by Thyagarajan ( https://github.com/thyagarajank ) Project_File:https://github.com/thyagarajank/tensorflow-own-object-detection-model-in-google-colab

# %% [markdown]
# Note:
#
# **Go to runtime-->change runtime type--> GPU**
#
# (change to GPU if it is none)
#
# * working on support for tensorboard

# %% [markdown]
# **Step-1** Connect Google Drive (for storage)

# %%
# mount drive with colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Step-2** TensorFlow Installation

# %%
# !pip install tensorflow-gpu==1.15.0

# %% [markdown]
# **Step-3** Download tensorflow model garden (model.zip)

# %%
# !wget https://github.com/tensorflow/models/archive/refs/heads/r1.13.0.zip

# %%
# !unzip r1.13.0.zip

# %%
# !mv models-r1.13.0 models-master

# %% [markdown]
# If Use my repository model files. Download it (**Optional**)

# %%
# !wget https://github.com/thyagarajank/tensorflow-own-object-detection-model-in-google-colab

# %%
# !unzip master.zip

# %%
cp -a /model/. /content/models-master/research/object_detection/

# %% [markdown]
# **Step-4** Download model files

# %%
# %cd models-master/research/object_detection

# %% [markdown]
# Download Google sample the model (faster_rcnn_inception_v2_coco_2018_01_28)
# Check it https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/tf1_detection_zoo.md

# %%
# !wget http://download.tensorflow.org/models/object_detection/faster_rcnn_inception_v2_coco_2018_01_28.tar.gz

# %%
# !tar -zxvf faster_rcnn_inception_v2_coco_2018_01_28.tar.gz

# %%
# %cd ..

# %%
# !pwd

# %% [markdown]
# **Step-5** Tensor & Python Installation

# %%
# !python setup.py build
# !python setup.py install

# %%
# !pwd

# %% [markdown]
# **Step-6** Dependency tools installation

# %%
# !pip install pycocotools

# %%
# !protoc --python_out=. ./object_detection/protos/image_resizer.proto

# %%
# %%bash
# %cd models/research/
# protoc object_detection/protos/*.proto --python_out=.

# %%
# %%bash
# %cd models/research
# pip install .

# %%
pip install Cartopy==0.17.0

# %%
# !pip install -q matplotlib-venn
# !apt-get -qq install -y libfluidsynth1
# !apt-get -qq install -y libarchive-dev && pip install -q -U libarchive
import libarchive
# !apt-get -qq install -y graphviz && pip install -q pydot
import pydot
# !apt-get -qq install python-cartopy python3-cartopy
import cartopy

# %%
# %cd slim

# %%
# !python setup.py build
# !python setup.py install

# %%
# !pwd
# %cd ..
# %cd object_detection/

# %% [markdown]
# **Step-7** Upload Training dataset and tf.record files

# %%
# !cp -r /content/drive/'My Drive'/rccn.zip /content/models-master/research/object_detection/
# !unzip rccn.zip

# %%
cp -a /content/models-master/research/object_detection/rccn/. /content/models-master/research/object_detection/

# %%
# !cp -r /content/drive/'My Drive'/faster_rcnn_inception_v2_pets.config /content/models-master/research/object_detection/

# %% [markdown]
# **Step -8** Object Training

# %%
# !python train.py --logtostderr --train_dir=training/ --pipeline_config_path=faster_rcnn_inception_v2_pets.config

# %% [markdown]
# **Tensorboard Graph** (Training Loss Graph)

# %%
# %load_ext tensorboard
# %tensorboard --logdir=training/

# %% [markdown]
# **After Traning to copy all training files to google drive(backup)**
#
# **Note 1**: please backup every 3 hour there are chances of disconnection.
#
# **Note 2**: Google Colab 12 hour only training period is free, So backup the training files.

# %% [markdown]
# **A**:-Copy all training files to google drive(backup)

# %%
# !cp -r /content/models-master/research/object_detection/training/ /content/drive/'My Drive'/

# %% [markdown]
# **B**:-retrieve training file from Google Drive to Google Colab

# %%
# !cp -r /content/drive/'My Drive'/training/ /content/models-master/research/object_detection/

# %% [markdown]
# **Step-9** Final training model ckpt file to Pb file (Inference graph) Convertion

# %%
# !python export_inference_graph.py --input_type image_tensor --pipeline_config_path ssd_mobilenet_v2_quantized_300x300_coco.config --trained_checkpoint_prefix training/model.ckpt-XXXX --output_directory inference_graph

# %%
# !cp -r /content/models-master/research/object_detection/inference_graph/ /content/drive/'My Drive'/
